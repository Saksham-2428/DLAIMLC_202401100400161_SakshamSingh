# %%
import tensorflow as tf
import numpy as np

x = np.array([1,2,3,4],dtype=float)
y = np.array([2,4,6,8],dtype=float)

model = tf.keras.([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer="sgd",loss='mean_squared_error')

model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - loss: 87.8371
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 61.0029
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 42.3829
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 29.4625
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 20.4970
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 14.2757
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 9.9585
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 6.9627
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 4.8836
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.4406

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([1,2,3,4],dtype=float)
y = np.array([2,4,6,8],dtype=float)

model = Sequential([
    Dense(1,input_shape=(1,))
])

model.compile(optimizer="sgd",loss='mse')

model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 32.0912
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 22.2873
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 15.4845
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 10.7641
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 7.4885
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 5.2156
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 3.6383
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.5438
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.7842
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.2570

# %%
import torch
import torch.nn as nn
import torch.optim as optim

model = nn.Linear(1, 1)

criterion = nn.MSELoss()

optimizer = optim.SGD(model.parameters(), lr=0.01)

x = torch.tensor([[1.],[2.],[3.],[4.]])
y = torch.tensor([[2.],[4.],[6.],[8.]])

for epoch in range(10):
    optimizer.zero_grad()
    outputs = model(x)
    loss = criterion(outputs, y)
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 26.99087905883789
# Epoch 2, Loss: 18.72977066040039
# Epoch 3, Loss: 12.997553825378418
# Epoch 4, Loss: 9.02008056640625
# Epoch 5, Loss: 6.260188579559326
# Epoch 6, Loss: 4.345149993896484
# Epoch 7, Loss: 3.01633620262146
# Epoch 8, Loss: 2.0942931175231934
# Epoch 9, Loss: 1.4544987678527832
# Epoch 10, Loss: 1.0105515718460083
